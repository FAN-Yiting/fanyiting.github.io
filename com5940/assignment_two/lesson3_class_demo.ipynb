# %%
from flask import Flask, render_template
import requests


app = Flask(__name__)

@app.route("/")
def home():
    user = {"name":"FAN"}
    headers = {'Authorization': 'Bearer keyGUZoAEsuZnDjWU',}
    params = (('view', 'Grid view'),)

    r = requests.get('https://api.airtable.com/v0/appTPlThl5MamShOK/All?api_key=keyGUZoAEsuZnDjWU', headers=headers, params=params)
    dict = r.json()
    dataset = []
    
    for i in dict['records']:
         dict = i['fields']
         dataset.append(dict)
    #  {% for row in dataset  %}{{ row["name"] }}{% endfor %}
    return render_template('home.html',album_user=user, dataset=dataset)


@app.route("/about_us")
def about_us():
    return render_template('about_us.html')

if __name__ == '__main__':
    from werkzeug.serving import run_simple
    run_simple('localhost', 9002, app)
# if __name__ == '__main__':
   # app.run(debug = True)
# Out:
#  * Running on http://localhost:9002/ (Press CTRL+C to quit)
