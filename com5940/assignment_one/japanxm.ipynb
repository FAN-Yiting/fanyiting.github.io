# %%
# !pip install PyMySQL

# %%
import pymysql.cursors
connection = pymysql.connect(host="localhost", 
                     user="root",   
                     passwd="root", 
                     db="japanxm",   
                     charset='utf8mb4',
                     cursorclass=pymysql.cursors.DictCursor)

# %%
with connection.cursor() as cursor:
        sql = "SELECT * FROM `table 2`"
        cursor.execute(sql)
        result = cursor.fetchall()
        dataset = []
        temp = {}
        i = 0
        for row in result:
            temp[i] = row
            dataset.append(temp[i])
            i = i + 1
        print('\n')
        print(dataset)
        print('\n')
# Out:
# [{'餐厅名称': '六厘舍', '图片': '六.jpg (https://dl.airtable.com/.attachments/71eee86dff3e6675067a705a426b5d55/9087effd.jpg)', '食物类型': '日本料理', '地点': '厦门大学', '人均消费': '57/人', '综合评分': Decimal('4.91'), '口味评分': Decimal('4.89'), '环境评分': Decimal('4.88'), '服务评分': Decimal('4.91')}, {'餐厅名称': '菡SUSHI', '图片': '菡.jpg (https://dl.airtable.com/.attachments/66fa2ed6cda648f7ad478b4867f0539b/65fe6718.jpg)', '食物类型': '日本料理', '地点': '中山路/轮渡', '人均消费': '317/人', '综合评分': Decimal('4.88'), '口味评分': Decimal('4.91'), '环境评分': Decimal('4.90'), '服务评分': Decimal('4.89')}, {'餐厅名称': '鮨一日本料理', '图片': '之一.jpg (https://dl.airtable.com/.attachments/0b9f4a60c40d54b4be8e7cfb3340802f/d58a6605.jpg)', '食物类型': '日本料理', '地点': '禾祥西路', '人均消费': '1350/人', '综合评分': Decimal('4.89'), '口味评分': Decimal('4.88'), '环境评分': Decimal('4.85'), '服务评分': Decimal('4.90')}, {'餐厅名称': '森空和食', '图片': '森空.jpg (https://dl.airtable.com/.attachments/a828e3650142bb0ad624de0a15b84a62/da395518.jpg)', '食物类型': '日本料理', '地点': '中华城', '人均消费': '149/人', '综合评分': Decimal('4.88'), '口味评分':
# ...

# %%
import requests

headers = {
'Authorization': 'Bearer keyGUZoAEsuZnDjWU',
}

params = (
('view', 'Grid view'),
)

r = requests.get('https://api.airtable.com/v0/appVh4v3JqwQBxx2T/%E6%80%BB%E8%A1%A8?api_key=keyGUZoAEsuZnDjWU', headers=headers, params=params)
dict = r.json()
dataset = []
productID = []
productCode = []
name = []
for i in dict['records']:
     dict = i['fields']
     dataset.append(dict)
print(dataset)
print('\n')
# Out:
# [{'餐厅名称': '六厘舍', '地点': '厦门大学', '综合评分': 4.91, '人均消费': '57/人', '口味评分': 4.89, '环境评分': 4.88, '服务评分': 4.91, '图片': [{'id': 'attm1rrGmaPzG73JT', 'url': 'https://dl.airtable.com/.attachments/71eee86dff3e6675067a705a426b5d55/9087effd.jpg', 'filename': '六.jpg', 'size': 44977, 'type': 'image/jpeg', 'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/1e8c073ad59000fb6de6090644082f16/d1a6c72d', 'width': 54, 'height': 36}, 'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/a7ec34077296a730661bdacd6bf62613/66a3e8ca', 'width': 700, 'height': 466}, 'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/b1ae2979f281def87710c507a104acb4/532d7e14', 'width': 3000, 'height': 3000}}}], '食物类型': '日本料理'}, {'餐厅名称': '菡SUSHI', '地点': '中山路/轮渡', '综合评分': 4.88, '人均消费': '317/人', '口味评分': 4.91, '环境评分': 4.9, '服务评分': 4.89, '图片': [{'id': 'attmswZMwh6kO5Wkc', 'url': 'https://dl.airtable.com/.attachments/66fa2ed6cda648f7ad478b4867f0539b/65fe6718.jpg', 'filename': '菡.jpg', 'size
# ...
